# %%
# !pip install -q -U google-generativeai

# %%
# @title Generate Text From Image
image_path = "/content/dice.jpeg" # @param {type:"string"}
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

from google.colab import userdata
import PIL.Image


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

img = PIL.Image.open(image_path)

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro-vision')

response = model.generate_content(img)

to_markdown(response.text)
# Out:
# >  The image shows three white dice on a chessboard. The dice are arranged in a triangle, with one die on top of the other two. The top die is facing up, and it shows a 5. The die in the middle is facing down, and it shows a 2. The die on the bottom is facing up, and it shows a 4.
