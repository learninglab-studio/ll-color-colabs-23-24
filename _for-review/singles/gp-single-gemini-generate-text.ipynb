# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 2.3 MB/s eta 0:00:00

# %%
# @title Generate Text
prompt = "tell me about google gemini" # @param {type:"string"}
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

from google.colab import userdata

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))



GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content(prompt)

print("here is some feedback on your prompt")
print(response.prompt_feedback)

to_markdown(response.text)
# Out:
# here is some feedback on your prompt
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# > **Google Gemini**
# >
# > Google Gemini is a machine learning platform that enables developers to build and train AI models at scale. It provides a unified interface and set of tools for the entire machine learning lifecycle, including data preparation, model training, hyperparameter tuning, and model deployment.
# >
# > **Key Features:**
# >
# > * **Data Preprocessing:** Gemini provides tools for data cleaning, feature engineering, and data transformation.
# > * **Model Training:** It supports training of various machine learning models using different algorithms, such as linear regression, logistic regression, decision trees, and neural networks.
# > * **Hyperparameter Tuning:** Gemini offers automated hyperparameter tuning to optimize model performance.
# > * **Model Deployment:** Deploys trained models to different platforms, including mobile, web, and cloud.
# > * **Cloud-Based:** Gemini is a cloud-based platform, allowing developers to access and use its resources from anywhere with an internet connection.
# > * **Scalability:** Gemini can handle large-scale datasets and models, making it suitable for complex AI applications.
# > * **Integration with Cloud ML APIs:** Gemini integrates with other Google Cloud Machine Learning APIs, such as AutoML and BigQuery, for seamless data and model management.
# >
# > **Benefits:**
# >
# > * **Accelerated ML Development:** Simplification of the machine learning development process.
# > * **Improved Model Performance:** Automated hyperparameter tuning enhances model accuracy and efficiency.
# > * **Reduced Infrastructure Costs:** Cloud-based platform eliminates the need for expensive hardware investments.
# > * **Enhanced Scalability:** Can handle large datasets and models, enabling businesses to scale their AI solutions.
# > * **Increased Collaboration:** Facilitates teamwork by providing a shared workspace for developers and data scientists.
# >
# > **Use Cases:**
# >
# > Gemini is used across a wide range of industries, including:
# >
# > * Healthcare: Disease diagnosis, patient monitoring
# > * Finance: Risk assessment, fraud detection
# > * Retail: Personalized recommendations, inventory optimization
# > * Transportation: Traffic prediction, route planning
# > * Cybersecurity: Threat detection, anomaly detection
# >
# > **Availability:**
# >
# > Google Gemini is currently in beta and available to a limited number of users.

# %%
# @title Stream Response
from time import sleep
prompt = "tell me about google gemini" # @param {type:"string"}

response = model.generate_content(prompt, stream=True)
for chunk in response:
  print(chunk.text)
  print("_"*50)
  sleep(0.3)
# Out:
# **Google Gemini**
#
# Google Gemini is a mobile advertising platform designed specifically for app
# __________________________________________________
#  developers and agencies who want to drive app installs and engagement. It is part of the Google Ads suite of advertising solutions.
#
# **Key Features:**
#
# * **
# __________________________________________________
# Cross-app campaigns:** Gemini allows you to target users across multiple apps, increasing your reach and maximizing your advertising impact.
# * **In-app bidding:** With real-time bidding, you can compete for every ad impression in participating apps, giving you more control over your ad placement and costs.
# * **Optimized
# __________________________________________________
#  targeting:** Gemini uses machine learning algorithms to target users based on specific criteria, such as demographics, interests, and app usage behavior.
# * **Precise measurement:** Gemini provides detailed reporting and analytics to track the performance of your campaigns and measure the impact on app installs and engagement.
#
# **Benefits:**
#
# * **Increased app installs:** Gemini helps you reach more users and drive more app installs.
# * **Improved engagement:** By targeting users who are more likely to be interested in your app, you can increase engagement and drive conversions.
# * **Reduced costs:** The in-app bidding system allows you to optimize your bids and reduce your overall
# __________________________________________________
#  advertising costs.
# * **Simplified management:** Gemini's user-friendly interface makes it easy to create and manage your campaigns.
#
# **How Gemini Works:**
#
# 1. **Create a campaign:** Set up your campaign goals, budget, and target audience.
# 2. **Upload your ad creatives:** Provide high-quality images and videos that showcase your app.
# 3. **Select your targeting options:** Define the specific criteria you want your ads to target.
# 4. **Set your bids:** Decide how much you are willing to pay for each ad impression.
# 5. **Monitor performance:** Track your campaign results and make adjustments as needed to optimize performance.
#
# **Industries Best Suited for Gemini:**
#
# Gemini is suitable for app developers and agencies in various industries, including:
#
# * Gaming
# * E-commerce
# * Travel
# * Social media
# * Finance
# * Health and wellness
#
# **Pricing:**
#
# Gemini operates on a cost-per-click (CPC) or cost-per-mile (CPM) basis. You only pay when users click on your ads or when your ads are displayed a certain number of times.
# __________________________________________________
