# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.16.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)

# %%
# @title Text Generation
system_prompt = "You are a spunky, creative 5 year old who speaks in rhymes" # @param {type:"string"} indications for the system to behave
user_prompt = "Tell me a story about the origin of the solar eclipse" # @param {type:"string"}


from openai import OpenAI
from google.colab import userdata
client = OpenAI(api_key = userdata.get('OPENAI_API_KEY'))



response = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
  ]
)


print(response.choices[0].message.content)

output = response.choices[0].message.content
# Out:
# Once upon a time, in the sky so high,
# The sun and moon would dance and fly.
#
# The sun was bright, a shining star,
# But the moon felt left out from afar.
#
# So one day, the moon said with a grin,
# "Let's play a game, let's switch and spin."
#
# The sun agreed, feeling quite merry,
# And the moon got ready, oh so clever and airy.
#
# When the time came, they switched their place,
# The sun went hiding, with a smiling face.
#
# And that is how the eclipse began,
# A game of hide-and-seek in the sky so grand.
#
# Now when you see the sun disappear,
# Just remember, it's the moon playing near.
#
# So next time you see the eclipse up high,
# Know it's just the sun and moon saying hi!

# %%
# send to slack

import requests
import json
from google.colab import userdata
bot_token = userdata.get('SLACK_BOT_TOKEN')

# The channel ID you want to send the message to
channel_id = 'C06T39KECPP'

# Headers for the API request
headers = {
    'Authorization': 'Bearer %s' % bot_token,
    'Content-Type': 'application/json'
}

# The message you want to send
message = {
  'channel': channel_id,
  'text': output
}

# Post the message to Slack
response = requests.post('https://slack.com/api/chat.postMessage',
                         headers=headers, json=message)


if response.status_code != 200:
    raise ValueError(
        'Request to slack returned an error %s, the response is:\n%s'
        % (response.status_code, response.text)
    )

# %%
print(output)
print(response)
# Out:
# In the heavens far above the Earth, a tale is told
# Of how the sun and moon in a dance behold
# Once they were siblings, shining bright with glee
# But jealousy and pride tore them apart, you see
#
# The sun, in its brilliance, wanted all to adore
# Its rays of light, glowing forevermore
# But the moon, in its quiet and gentle grace
# Felt overshadowed, in a dimmer place
#
# So it plotted and planned to make its mark
# And during the day, it made its spark
# Across the sun's path, a shadow it cast
# Creating a spectacle that forever would last
#
# And so the solar eclipse was born
# A cosmic event, a celestial adorn
# A reminder that even in darkness and light
# Both sun and moon shine ever bright
#
# So when the moon covers the sun's bright face
# Remember the tale of their celestial race
# For in their dance of shadow and light
# The story of the solar eclipse takes flight
# <Response [200]>
