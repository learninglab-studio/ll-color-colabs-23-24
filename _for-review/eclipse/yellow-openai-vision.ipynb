# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# @title Ask About an Image
from google.colab import userdata
isURL = True # @param {type:"boolean"}
prompt = "describe the image" # @param {type:"string"}
image = "/content/mix.png" # @param {type:"string"}


if isURL:
  print("URL option selected")
  from openai import OpenAI

  client = OpenAI(api_key = userdata.get('OPENAI_API_KEY'))

  response = client.chat.completions.create(
    model="gpt-4-vision-preview",
    messages=[
      {
        "role": "user",
        "content": [
          {"type": "text", "text": prompt},
          {
            "type": "image_url",
            "image_url": {
              "url": image,
            },
          },
        ],
      }
    ],
    max_tokens=300,
  )

  print(response.choices[0].message.content)
else:
  print("Image File option selected")
  import base64
  import requests

  # OpenAI API Key
  api_key = userdata.get('OPENAI_API_KEY')

  # Function to encode the image
  def encode_image(image_path):
    with open(image_path, "rb") as image_file:
      return base64.b64encode(image_file.read()).decode('utf-8')

  # Path to your image
  image_path = image

  # Getting the base64 string
  base64_image = encode_image(image_path)

  headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
  }

  payload = {
    "model": "gpt-4-vision-preview",
    "messages": [
      {
        "role": "user",
        "content": [
          {
            "type": "text",
            "text": prompt
          },
          {
            "type": "image_url",
            "image_url": {
              "url": f"data:image/jpeg;base64,{base64_image}"
            }
          }
        ]
      }
    ],
    "max_tokens": 300
  }

  response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

  print(response.json()["choices"][0]["message"]["content"])
  # print(response.json().choices[0].message.content)
# Out:
# Image File option selected
# The image depicts a photoshopped creature that is a combination of two different animals. The body of the creature, including its legs and tail, resembles that of a tiger, characterized by its orange fur with black stripes. However, the head of the creature is that of a wolf, with grey and white fur and the distinct facial features of a wolf. The background of the image is white, making the hybrid animal stand out clearly. This is a fictional creature created through digital manipulation and does not exist in nature.
# not implemented yet

# %% [markdown]
# Check the `isURL` box to indicate if the image format is a URL or an uploaded file.
# write the prompt to ask about the image under the `prompt` variable.
# Input either the image url or image path under the `image` variable
