# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GEMINI_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
Color = "red" # @param {type:"string"}

title = f"Little {Color} Riding Hood"

# %%
# %%time
response = model.generate_content("Write a creative and playful five-paragraph story inspired by Bruno Munari's variants of Little Red Riding Hood. The main character's name is \"{title}\", and the color theme is \"{Color}\"",)
# Out:
# CPU times: user 241 ms, sys: 20.2 ms, total: 262 ms
# Wall time: 17.8 s

# %%
print(response.__dict__)

if hasattr(response, 'actual_attribute'):
    parts = response.actual_attribute  # Adjust this line based on the actual structure
    for part in parts:
        if "text" in part:
            markdown_content = to_markdown(part["text"])
            print(markdown_content)
        else:
            print("Found a part without text:", part)
else:
    print("The response does not have the expected attribute.")
# Out:
# {'_done': True, '_iterator': None, '_result': candidates {
#   finish_reason: SAFETY
#   index: 0
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: HIGH
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# prompt_feedback {
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# , '_chunks': [candidates {
#   finish_reason: SAFETY
#   index: 0
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: HIGH
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# prompt_feedback {
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# ], '_error': None}
# The response does not have the expected attribute.

# %%
# %%time
snowwhite = model.generate_content("Write a creative and playful five-paragraph story inspired by Snow White but instead called Raven Lash, referring to the color of the protagonist's eyelashes",)
# Out:
# CPU times: user 92.9 ms, sys: 11.2 ms, total: 104 ms
# Wall time: 6.24 s

# %%
generated_content = snowwhite.text
print(f"```markdown\n{generated_content}\n```")
# Out:
# ```markdown
# In the enchanted realm of Ravenwood, where nature whispered secrets and magic danced in the moonlight, there lived an extraordinary princess named Raven Lash. Her eyes sparkled with an emerald green, and her most striking feature was her raven-black eyelashes that cascaded down her face like a delicate waterfall.
#
# One fateful day, as Raven strolled through the whispering willows, her laughter echoed through the rustling leaves. Suddenly, a dark shadow fell upon the path, and a wicked witch emerged from the gloom. With a cackle, the witch cast a curse upon Raven, condemning her to an eternal slumber.
#
# As the curse took hold, Raven's eyes fluttered closed, and her body fell limp. The forest grew silent, mourning the loss of its beloved princess. Yet, amidst the despair, a glimmer of hope emerged. Seven tiny birds, each representing a different color of the rainbow, flew down from the heavens.
#
# With gentle beaks, they pecked at Raven's eyelashes, their vibrant colors mingling with the darkness. Each peck infused her with a spark of life, her eyelashes shimmering with iridescent hues. As the last bird bestowed its touch, Raven's eyes slowly opened, their emerald glow shining brighter than ever before.
#
# Awakened from her slumber, Raven found that the curse had transformed her into a protector of the realm. Her raven-black eyelashes, once a sign of slumber, now became a symbol of her newfound power. And so, Raven Lash became the guardian of Ravenwood, her laughter and the vibrant colors of her eyelashes forever illuminating the enchanted forest.
# ```

# %%
print(snowwhite.__dict__)

if hasattr(snowwhite, 'actual_attribute'):
    parts = snowwhite.actual_attribute  # Adjust this line based on the actual structure
    for part in parts:
        if "text" in part:
            markdown_content = to_markdown(part["text"])
            print(markdown_content)
        else:
            print("Found a part without text:", part)
else:
    print("The response does not have the expected attribute.")
# Out:
# {'_done': True, '_iterator': None, '_result': candidates {
#   content {
#     parts {
#       text: "In the enchanted realm of Ravenwood, where nature whispered secrets and magic danced in the moonlight, there lived an extraordinary princess named Raven Lash. Her eyes sparkled with an emerald green, and her most striking feature was her raven-black eyelashes that cascaded down her face like a delicate waterfall.\n\nOne fateful day, as Raven strolled through the whispering willows, her laughter echoed through the rustling leaves. Suddenly, a dark shadow fell upon the path, and a wicked witch emerged from the gloom. With a cackle, the witch cast a curse upon Raven, condemning her to an eternal slumber.\n\nAs the curse took hold, Raven\'s eyes fluttered closed, and her body fell limp. The forest grew silent, mourning the loss of its beloved princess. Yet, amidst the despair, a glimmer of hope emerged. Seven tiny birds, each representing a different color of the rainbow, flew down from the heavens.\n\nWith gentle beaks, they pecked at Raven\'s eyelashes, their vibrant colors mingling with the darkness. Each peck infused her with a spark of life, her eyelashes shimmering with iridescent hues. As the last bird bestowed its touch, Raven\'s eyes slowly opened, their emerald glow shining brighter than ever before.\n\nAwakened from her slumber, Raven found that the curse had transformed her into a protector of the realm. Her raven-black eyelashes, once a sign of slumber, now became a symbol of her newfound power. And so, Raven Lash became the guardian of Ravenwood, her laughter and the vibrant colors of her eyelashes forever illuminating the enchanted forest."
#     }
#     role: "model"
#   }
#   finish_reason: STOP
#   index: 0
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# prompt_feedback {
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# , '_chunks': [candidates {
#   content {
#     parts {
#       text: "In the enchanted realm of Ravenwood, where nature whispered secrets and magic danced in the moonlight, there lived an extraordinary princess named Raven Lash. Her eyes sparkled with an emerald green, and her most striking feature was her raven-black eyelashes that cascaded down her face like a delicate waterfall.\n\nOne fateful day, as Raven strolled through the whispering willows, her laughter echoed through the rustling leaves. Suddenly, a dark shadow fell upon the path, and a wicked witch emerged from the gloom. With a cackle, the witch cast a curse upon Raven, condemning her to an eternal slumber.\n\nAs the curse took hold, Raven\'s eyes fluttered closed, and her body fell limp. The forest grew silent, mourning the loss of its beloved princess. Yet, amidst the despair, a glimmer of hope emerged. Seven tiny birds, each representing a different color of the rainbow, flew down from the heavens.\n\nWith gentle beaks, they pecked at Raven\'s eyelashes, their vibrant colors mingling with the darkness. Each peck infused her with a spark of life, her eyelashes shimmering with iridescent hues. As the last bird bestowed its touch, Raven\'s eyes slowly opened, their emerald glow shining brighter than ever before.\n\nAwakened from her slumber, Raven found that the curse had transformed her into a protector of the realm. Her raven-black eyelashes, once a sign of slumber, now became a symbol of her newfound power. And so, Raven Lash became the guardian of Ravenwood, her laughter and the vibrant colors of her eyelashes forever illuminating the enchanted forest."
#     }
#     role: "model"
#   }
#   finish_reason: STOP
#   index: 0
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# prompt_feedback {
#   safety_ratings {
#     category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HATE_SPEECH
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_HARASSMENT
#     probability: NEGLIGIBLE
#   }
#   safety_ratings {
#     category: HARM_CATEGORY_DANGEROUS_CONTENT
#     probability: NEGLIGIBLE
#   }
# }
# ], '_error': None}
# The response does not have the expected attribute.

# %%
# Check if response.parts is accessible and not empty
print("Checking response.parts:", snowwhite.parts)

markdown_parts = []
for part in snowwhite.parts:
    # Debug print to check each part
    print("Inspecting part:", part)
    if "text" in part:
        # Convert the text part to Markdown and add it to the list
        markdown_content = to_markdown(part["text"])
        markdown_parts.append(markdown_content)
        # Debug print to check the markdown conversion
        print("Markdown content:", markdown_content)
    else:
        # If part does not contain "text", print what it contains
        print("Non-text part found:", part)

# Check if markdown_parts is empty
if not markdown_parts:
    print("No markdown parts were added. Check the response structure and to_markdown function.")
else:
    # Now, `markdown_parts` contains the Markdown-converted text of each part
    # You can join them or process them as needed
    markdown_response = "\n".join(markdown_parts)
    print(markdown_response)
# Out:
# Checking response.parts: [text: "In the enchanted realm of Ravenwood, where nature whispered secrets and magic danced in the moonlight, there lived an extraordinary princess named Raven Lash. Her eyes sparkled with an emerald green, and her most striking feature was her raven-black eyelashes that cascaded down her face like a delicate waterfall.\n\nOne fateful day, as Raven strolled through the whispering willows, her laughter echoed through the rustling leaves. Suddenly, a dark shadow fell upon the path, and a wicked witch emerged from the gloom. With a cackle, the witch cast a curse upon Raven, condemning her to an eternal slumber.\n\nAs the curse took hold, Raven\'s eyes fluttered closed, and her body fell limp. The forest grew silent, mourning the loss of its beloved princess. Yet, amidst the despair, a glimmer of hope emerged. Seven tiny birds, each representing a different color of the rainbow, flew down from the heavens.\n\nWith gentle beaks, they pecked at Raven\'s eyelashes, their vibrant colors mingling with the darkness. Each peck infused her with a spark of life, her eyelashes shimmering with iridescent hues. As the last bird bestowed its touch, Raven\'s eyes slowly opened, their emerald glow shining brighter than ever before.\n\nAwakened from her slumber, Raven found that the curse had transformed her into a protector of the realm. Her raven-black eyelashes, once a sign of slumber, now became a symbol of her newfound power. And so, Raven Lash became the guardian of Ravenwood, her laughter and the vibrant colors of her eyelashes forever illuminating the enchanted forest."
# ]
# Inspecting part: text: "In the enchanted realm of Ravenwood, where nature whispered secrets and magic danced in the moonlight, there lived an extraordinary princess named Raven Lash. Her eyes sparkled with an emerald green, and her most striking feature was her raven-black eyelashes that cascaded down her face like a delicate waterfall.\n\nOne fateful day, as Raven strolled through the whispering willows, her laughter echoed through the rustling leaves. Suddenly, a dark shadow fell upon the path, and a wicked witch emerged from the gloom. With a cackle, the witch cast a curse upon Raven, condemning her to an eternal slumber.\n\nAs the curse took hold, Raven\'s eyes fluttered closed, and her body fell limp. The forest grew silent, mourning the loss of its beloved princess. Yet, amidst the despair, a glimmer of hope emerged. Seven tiny birds, each representing a different color of the rainbow, flew down from the heavens.\n\nWith gentle beaks, they pecked at Raven\'s eyelashes, their vibrant colors mingling with the darkness. Each peck infused her with a spark of life, her eyelashes shimmering with iridescent hues. As the last bird bestowed its touch, Raven\'s eyes slowly opened, their emerald glow shining brighter than ever before.\n\nAwakened from her slumber, Raven found that the curse had transformed her into a protector of the realm. Her raven-black eyelashes, once a sign of slumber, now became a symbol of her newfound power. And so, Raven Lash became the guardian of Ravenwood, her laughter and the vibrant colors of her eyelashes forever illuminating the enchanted forest."
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-c998eb51378f> in <cell line: 5>()
#       8     if "text" in part:
#       9         # Convert the text part to Markdown and add it to the list
# ---> 10         markdown_content = to_markdown(part["text"])
#      11         markdown_parts.append(markdown_content)
#      12         # Debug print to check the markdown conversion
#
# TypeError: 'Part' object is not subscriptable
