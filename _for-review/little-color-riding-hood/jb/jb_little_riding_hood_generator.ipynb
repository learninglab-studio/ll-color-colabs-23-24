# %% [markdown]
# # JB Little Riding Hood Generator
#
# Here I have created a "machine" that uses API's from Open AI to generate a story  inspired by Bruno Munari's series of Little [color] Riding Hood. The user input is a photo, to which the generator matches with the closest pantone color. The name of the pantone color will be in the title of the story, namely "Little [color] Riding Hood". A text generator API writes a storyline based on a prompt, and then a DALL-E API is used to generates a series of images based on the plot. Lastly the machine creates a PDF of the story and saves it to drive.
#
# <br>
#
# **Way to use:**
#
# * Set up the machine by running the cells under "Setup"
# * Color match photo to pantone color
#   * Download json file for pantone color: https://drive.google.com/file/d/1Sx642yB5i4smqXsA5QKrHeHpX0nQ-LNG/view *(Make sure that the file is saved in MyDrive and not in a folder)*
#   * Upload a photo of choice from drive
# * Generate story inspired by pantone color by running the cell under "Story generator"
# * Save PDF of story to drive by running the cell under "Create and save PDF"
#
# <br>
#
# ENJOY!

# %% [markdown]
# ## Setup

# %% [markdown]
# Setting up the machine requires installing dependencies, connecting colab to drive and retrieving and API key. You can run the following three cells without worrying about what they do.

# %% [markdown]
# ### Install your dependencies

# %% [markdown]
# These commands are used to install software packages in Python, which are collections of pre-written code that can be used to add functionality to your Python projects without having to write the code yourself. When you run these commands in Google Colab, you're asking for specific tools and libraries to be downloaded and installed on your computer or in your online environment.

# %%
# !pip install openai tiktoken requests orjson reportlab
# !pip3 install opencv-python
# Out:
# Collecting openai
#   Downloading openai-1.25.1-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 kB 4.1 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Collecting orjson
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 2.6 MB/s eta 0:00:00
# Collecting reportlab
#   Downloading reportlab-4.2.0-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (9.4.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab) (5.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Installing collected packages: reportlab, orjson, h11, tiktoken, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.25.1 orjson-3.10.3 reportlab-4.2.0 tiktoken-0.6.0
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)

# %% [markdown]
# ### Connect colab to drive

# %% [markdown]
# The following code connects your Google Colab notebook to your Google Drive. It's like telling your notebook, "Hey, let's use the files and folders I have stored in my Google Drive."

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Retrieve API key

# %% [markdown]
# To use Open AI API's we need a key. The following code sets up a connection to OpenAI's API within a Google Colab environment, using an API key stored in Colab's user data.

# %%
from google.colab import userdata
from openai import OpenAI
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')

client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %% [markdown]
# ## Generate Story

# %% [markdown]
# Generate your own Little [color] Riding Hood story by following the unstructions below!

# %% [markdown]
# ### Pantone color selection

# %% [markdown]
# This code is designed to identify colors within a photo and match them with the closest Pantone Color. The code returns the name and hex code of the closest pantone color and stores them in the variables pantone_color_name and pantone_color_hex. Because the pantone color names are not always the most descriptive, the code also returns the general name of the color as defined by CSS3 stored in the variable color_name. These variables are then used in the next cell where we create our story and images. To download JSON file of pantone colors, click here: https://drive.google.com/file/d/1Sx642yB5i4smqXsA5QKrHeHpX0nQ-LNG/view?usp=sharing

# %%
import cv2
import json
import webcolors
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import euclidean

''' Upload a photo from drive by clicking the folder icon on the left side, "drive",
 "MyDrive", locate your photo, click on the three dots on the right side and then
 "copy path". Paste the path below: '''
img = cv2.imread("path to photo")
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Choose the number of pantone colors you want to output
num_pantone_colors = 6

# Color quanitization
pixels = hsv_img.reshape((-1, 3))
pixels = np.float32(pixels)
num_colors = 1
kmeans = KMeans(n_clusters=num_colors)
kmeans.fit(pixels)
color_hsv =np.uint8(kmeans.cluster_centers_)

# Load pantone colors from Marlon
with open('/content/drive/MyDrive/pantone-colors-fixed.json') as file:
    pantone_colors = json.load(file)

# Function to find the closest Pantone color for a given HSV color
def find_closest_pantone(color_hsv, pantone_colors):
    distances = []
    for pantone in pantone_colors:
        pantone_hsv = np.array([pantone['H'], pantone['S'], pantone['V']])
        distance = euclidean(color_hsv, pantone_hsv)
        distances.append((pantone['Name'], pantone['HexCode'], distance))

    # Sort the distances list by the distance value
    distances.sort(key=lambda x: x[2])

    # Return the names and HexCodes of the six closest Pantone colors
    return [(name, hexcode) for name, hexcode, _ in distances[:num_pantone_colors]]

# Creates array of the name and hexcode of the closest pantone colors
closest_pantone_colors = find_closest_pantone(color_hsv.flatten(), pantone_colors)

# Define variables
pantone_color_name = closest_pantone_colors[0][0]
pantone_color_hex = closest_pantone_colors[0][1]

# Functions to find the closest named color to hex code
def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def hex_to_color_name(hex_code):
    rgb_tuple = webcolors.hex_to_rgb(hex_code)
    color_name = closest_color(rgb_tuple)
    return color_name

# find name of color
color_name = hex_to_color_name(pantone_color_hex)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-4833280aeba8> in <cell line: 12>()
#      10  "copy path". Paste the path below: '''
#      11 img = cv2.imread("path to photo")
# ---> 12 hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#      13
#      14 # Choose the number of pantone colors you want to output
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ### Story generator

# %% [markdown]
# This code creates a story inspired by Bruno Munari's variants of Little Red Riding Hood. Here I have used a text generator API that writes a story based on the input variable called *prompt*. A DALL-E API generates an image to each paragraph as specified by the image prompt.

# %%
from IPython.display import display, Image
import requests
import textwrap

title = f"Little {pantone_color_name} Riding Hood"

prompt = f"Write a creative and playful five-paragraph story inspired by Bruno Munari's variants of Little Red Riding Hood. The main character's name is called \"{title}\", and the color theme is \"{color_name}\". Include one or more side characters that match the color \"{color_name}\". Incorporate elements of simplicity, visual exploration, and tactile experiences similar to Munari's children's books."

story = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": prompt,}
  ]
)

paragraphs = story.choices[0].message.content.split('\n\n')

image_urls = []

for i, paragraph in enumerate(paragraphs):

    # Generate the image
    image = client.images.generate(
        model="dall-e-3",
        prompt= f"Create an illustration to this storyline: {paragraph[:60]}. The color in the image should correspond to the hex code \"{color_name}\". The picture should look like very simple scribbles with few details. It is important that the style is in watercolors, thin lines that are not connected to eachother, rapidly done, repetitive patterns, no shading or depth, monochrome. There should be mostly negative space and lots of air in the picture. Capture the characters and main happenings in the story",
        size="1024x1024",
        quality="standard",
        n=1,
    )

    # Display the paragraph text
    print_wrapped(f"{paragraph}\n")

    # Display the image
    image_url = image.data[0].url
    display(Image(url=image_url))

    # Append to list
    image_urls.append(image_url)
# Out:
# Once upon a time, in a land where the hills rolled in shades of #ffa64f, there
# lived a little girl with a name as vibrant as her surroundings—Sunny. Sunny
# loved to wander through the sun-kissed meadows, her laughter echoing like a
# bright melody in the air. Her grandmother, a skilled weaver, had gifted her a
# cloak woven from threads as golden as the sun itself, #ffa64f in hue. The cloak
# shimmered in the light, casting a warm glow wherever Sunny went.
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-uz05wK0H2DJBmWamMgNzym36.png?st=2024-03-08T19%3A27%3A33Z&se=2024-03-08T21%3A27%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A09%3A46Z&ske=2024-03-09T18%3A09%3A46Z&sks=b&skv=2021-08-06&sig=dF5LO%2BcG6SsPPGw%2BsLgRGe17JwvF5CkcOamTq5L9WsY%3D"/>
# One day, as Sunny skipped through the fields, a mischievous fox named Marigold
# approached her. Marigold's fur was a mix of golden hues, blending seamlessly
# with the #ffa64f landscape. With a sly smile, Marigold devised a plan to trick
# Sunny, leading her off the path to her grandmother's cottage. Sunny, ever
# curious and trusting, followed the fox into the depths of the forest, her cloak
# fluttering behind her like a brilliant trail of sunshine.
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-mD1Jx2Ld2uxwaWl8e0s0Fqbp.png?st=2024-03-08T19%3A27%3A45Z&se=2024-03-08T21%3A27%3A45Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T03%3A17%3A31Z&ske=2024-03-09T03%3A17%3A31Z&sks=b&skv=2021-08-06&sig=Mf3NS480x6iBJI9P37tlPWk/k7JP/X4VkZIpPSravWU%3D"/>
# As they journeyed through the woods, the colors of the forest danced around them
# in a playful symphony of #ffa64f. Sunlight filtered through the leaves, creating
# patterns of gold and amber on the forest floor. Sunny delighted in the textures
# of the moss beneath her feet and the rough bark of the trees she passed, her
# senses alive with the simple pleasures of the natural world.
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-UJbNzymJGQSik4OUDqoDo8Vo.png?st=2024-03-08T19%3A28%3A01Z&se=2024-03-08T21%3A28%3A01Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T08%3A52%3A31Z&ske=2024-03-09T08%3A52%3A31Z&sks=b&skv=2021-08-06&sig=%2BAwObet%2BKcJ850qK6ttDKNkzWLZ8/pQo%2B7OcK4sfhY4%3D"/>
# When they arrived at the cottage, Marigold revealed her true intentions, hoping
# to snatch the golden cloak for herself. But Sunny, quick-witted and resourceful,
# outsmarted the fox with a clever ruse. She spun a tale about the magic of her
# cloak, convincing Marigold that it held powers beyond imagination. Intrigued by
# the possibility of such a treasure, Marigold eagerly agreed to a wager. If the
# cloak truly possessed magic, then it would be worth the risk.
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-TscBefO8bTXE0is8IETs9NID.png?st=2024-03-08T19%3A28%3A15Z&se=2024-03-08T21%3A28%3A15Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A10%3A42Z&ske=2024-03-09T18%3A10%3A42Z&sks=b&skv=2021-08-06&sig=YLSGSCx23lgP4pqqBtoF4AtRAGDg2zeidAfPBZnlOcU%3D"/>
# With a mischievous grin, Sunny wrapped the cloak around Marigold, the shimmering
# threads enveloping the fox in a warm embrace. To Marigold's surprise, the cloak
# did indeed possess a touch of magic, transforming her fur into a luminous shade
# of #ffa64f. The fox blinked in astonishment, her once sleek coat now ablaze with
# the color of the sun.
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-bNTB3l9rTBuuZgzbUIqs3KZx.png?st=2024-03-08T19%3A28%3A27Z&se=2024-03-08T21%3A28%3A27Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A12%3A49Z&ske=2024-03-09T18%3A12%3A49Z&sks=b&skv=2021-08-06&sig=QGVN9BHj3x4XVNnMxPcWdVO%2BZuDNd7XgkYUEEhkwNzY%3D"/>
# And so, with a newfound appreciation for the wonders of the world around her,
# Marigold bid Sunny farewell and retreated into the forest, her golden fur
# gleaming in the dappled light. Sunny, her cloak returned to her, continued on
# her journey through the colorful hills, her heart full of joy and her mind open
# to the endless possibilities of the world. And in that moment, amidst the
# vibrant hues of #ffa64f, Sunny knew that the magic of the world was never far
# from reach.
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-mjpvdPXGNQHgeK3IclHoqFNn.png?st=2024-03-08T19%3A28%3A39Z&se=2024-03-08T21%3A28%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A15%3A11Z&ske=2024-03-09T18%3A15%3A11Z&sks=b&skv=2021-08-06&sig=KcidrdNE7NZd6B9%2BqCuDalzCeEzPweLtyBGzBCwIcYM%3D"/>

# %% [markdown]
# ### Create and save pdf

# %% [markdown]
# This code is set up to create a PDF document using the ReportLab library in Python. The PDF is saved to MyDrive.

# %%
from reportlab.lib.pagesizes import letter, inch
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.enums import TA_CENTER
from reportlab.lib import colors
from io import BytesIO
import os, datetime

# Modify title
title_modified = title.replace(" ", "_").replace("/", "_").replace("\\", "_")
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# pdf creation and format
pdf_file_name = f"{title_modified}_{timestamp}.pdf"
pdf_output_path = "/content/drive/MyDrive"
os.makedirs(pdf_output_path, exist_ok=True)
pdf_file_path = os.path.join(pdf_output_path, pdf_file_name)

doc = SimpleDocTemplate(pdf_file_path, pagesize= (8.5 * inch, 8.5 * inch), leftMargin=5, rightMargin=5, topMargin=0, bottomMargin=0)
styles = getSampleStyleSheet()

# custom styling
custom_style = ParagraphStyle(
    'CustomStyle',
    parent=styles['Normal'],
    fontName='Courier',
    fontSize=11,
    leading=14,
    textColor=colors.black,
)

title_style = ParagraphStyle(
    'TitleStyle',
    parent=styles['Normal'],
    fontName='Courier',
    fontSize=24,
    leading=42,
    textColor=colors.black,
    alignment=TA_CENTER,
    spaceAfter=50,
)

story = []

story.append(Paragraph(title, title_style))
story.append(PageBreak())

for paragraph, image_url in zip(paragraphs, image_urls):

    # Add image (assuming you have a way to download or access the images)
    story.append(Image(image_url, width=8.5 * inch, height=450))  # Adjust size as needed
    story.append(Spacer(1, 12))

    # Add paragraph
    story.append(Paragraph(paragraph, custom_style))
    story.append(Spacer(1, 12))

    # Add a page break after each paragraph/image pair
    story.append(PageBreak())

# Build the PDF
doc.build(story)

print(f"PDF saved as {pdf_file_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read(name, mode)
#     522         try:
# --> 523             return open_for_read_by_name(name,mode)
#     524         except:
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read_by_name(name, mode)
#     462     try:
# --> 463         return open(name,mode)
#     464     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-uz05wK0H2DJBmWamMgNzym36.png?st=2024-03-08T19%3A27%3A33Z&se=2024-03-08T21%3A27%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A09%3A46Z&ske=2024-03-09T18%3A09%3A46Z&sks=b&skv=2021-08-06&sig=dF5LO%2BcG6SsPPGw%2BsLgRGe17JwvF5CkcOamTq5L9WsY%3D'
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read(name, mode)
#     529                         raise ValueError('Attempted untrusted host access')
# --> 530                 return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     531             except:
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in rlUrlRead(name)
#     475 def rlUrlRead(name):
# --> 476     return urlopen(name).read()
#     477
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 403: Server failed to authenticate the request. Make sure the value of Authorization header is formed correctly including the signature.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in __init__(self, fileName, ident)
#     642                     raise ValueError('imageReaderFlags values other than 0 are no longer supported; all images are interned now')
# --> 643                 fp = open_for_read(fileName,'b')
#     644                 if not isinstance(fp, BytesIO):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read(name, mode)
#     533     globals()['open_for_read'] = open_for_read
# --> 534     return open_for_read(name,mode)
#     535
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read(name, mode)
#     531             except:
# --> 532                 raise IOError('Cannot open resource "%s"' % name)
#     533     globals()['open_for_read'] = open_for_read
#
# OSError: Cannot open resource "https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-uz05wK0H2DJBmWamMgNzym36.png?st=2024-03-08T19%3A27%3A33Z&se=2024-03-08T21%3A27%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A09%3A46Z&ske=2024-03-09T18%3A09%3A46Z&sks=b&skv=2021-08-06&sig=dF5LO%2BcG6SsPPGw%2BsLgRGe17JwvF5CkcOamTq5L9WsY%3D"
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-2e3bd2c60b2d> in <cell line: 62>()
#      60
#      61 # Build the PDF
# ---> 62 doc.build(story)
#      63
#      64 print(f"PDF saved as {pdf_file_path}")
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/doctemplate.py in build(self, flowables, onFirstPage, onLaterPages, canvasmaker)
#    1315         if onLaterPages is _doNothing and hasattr(self,'onLaterPages'):
#    1316             self.pageTemplates[1].beforeDrawPage = self.onLaterPages
# -> 1317         BaseDocTemplate.build(self,flowables, canvasmaker=canvasmaker)
#    1318
#    1319 def progressCB(typ, value):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/doctemplate.py in build(self, flowables, filename, canvasmaker)
#    1080                 try:
#    1081                     first = flowables[0]
# -> 1082                     self.handle_flowable(flowables)
#    1083                     handled += 1
#    1084                 except:
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/doctemplate.py in handle_flowable(self, flowables)
#     929             canv = self.canv
#     930             #try to fit it then draw it
# --> 931             if frame.add(f, canv, trySplit=self.allowSplitting):
#     932                 if not isinstance(f,FrameActionFlowable):
#     933                     self._curPageFlowableCount += 1
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/frames.py in _add(self, flowable, canv, trySplit)
#     156             h = y - p - s
#     157             if h>0 or zeroSize:
# --> 158                 w, h = flowable.wrap(aW, h)
#     159             else:
#     160                 return 0
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/flowables.py in wrap(self, availWidth, availHeight)
#     509     def wrap(self, availWidth, availHeight):
#     510         #the caller may decide it does not fit.
# --> 511         return self.drawWidth, self.drawHeight
#     512
#     513     def draw(self):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/flowables.py in __getattr__(self, a)
#     503             return self._img
#     504         elif a in ('drawWidth','drawHeight','imageWidth','imageHeight'):
# --> 505             self._setup_inner()
#     506             return self.__dict__[a]
#     507         raise AttributeError("<Image @ 0x%x>.%s" % (id(self),a))
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/flowables.py in _setup_inner(self)
#     460         height = self._height
#     461         kind = self._kind
# --> 462         img = self._img
#     463         if img:
#     464             self.imageWidth, self.imageHeight = img.getSize()
#
# /usr/local/lib/python3.10/dist-packages/reportlab/platypus/flowables.py in __getattr__(self, a)
#     497         if a=='_img':
#     498             from reportlab.lib.utils import ImageReader  #this may raise an error
# --> 499             self._img = ImageReader(self._file)
#     500             if not isinstance(self._file,strTypes):
#     501                 self._file = None
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in __init__(self, fileName, ident)
#     653                     self.jpeg_fh = self._jpeg_fh
#     654             except:
# --> 655                 annotateException('\nfileName=%r identity=%s'%(fileName,self.identity()))
#     656
#     657     def identity(self):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in annotateException(msg, enc, postMsg, sep)
#    1174     '''add msg to the args of an existing exception'''
#    1175     t,v,b=sys.exc_info()
# -> 1176     rl_reraise(t,t(sep.join((_ for _ in (msg,str(v),postMsg) if _))),b)
#    1177
#    1178 def escapeOnce(data):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in rl_reraise(t, v, b)
#     136 def rl_reraise(t, v, b=None):
#     137     if v.__traceback__ is not b:
# --> 138         raise v.with_traceback(b)
#     139     raise v
#     140 def rl_add_builtins(**kwd):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in __init__(self, fileName, ident)
#     641                 if imageReaderFlags != 0:
#     642                     raise ValueError('imageReaderFlags values other than 0 are no longer supported; all images are interned now')
# --> 643                 fp = open_for_read(fileName,'b')
#     644                 if not isinstance(fp, BytesIO):
#     645                     tfp, fp = fp, BytesIO(fp.read())
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read(name, mode)
#     532                 raise IOError('Cannot open resource "%s"' % name)
#     533     globals()['open_for_read'] = open_for_read
# --> 534     return open_for_read(name,mode)
#     535
#     536 def open_and_read(name,mode='b'):
#
# /usr/local/lib/python3.10/dist-packages/reportlab/lib/utils.py in open_for_read(name, mode)
#     530                 return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     531             except:
# --> 532                 raise IOError('Cannot open resource "%s"' % name)
#     533     globals()['open_for_read'] = open_for_read
#     534     return open_for_read(name,mode)
#
# OSError:
# fileName='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-uz05wK0H2DJBmWamMgNzym36.png?st=2024-03-08T19%3A27%3A33Z&se=2024-03-08T21%3A27%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A09%3A46Z&ske=2024-03-09T18%3A09%3A46Z&sks=b&skv=2021-08-06&sig=dF5LO%2BcG6SsPPGw%2BsLgRGe17JwvF5CkcOamTq5L9WsY%3D' identity=[ImageReader@0x7e50c68bee00 filename='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-uz05wK0H2DJBmWamMgNzym36.png?st=2024-03-08T19%3A27%3A33Z&se=2024-03-08T21%3A27%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A09%3A46Z&ske=2024-03-09T18%3A09%3A46Z&sks=b&skv=2021-08-06&sig=dF5LO%2BcG6SsPPGw%2BsLgRGe17JwvF5CkcOamTq5L9WsY%3D'] Cannot open resource "https://oaidalleapiprodscus.blob.core.windows.net/private/org-vvnfQBL4vlR6Sl0qTlqz16Oh/user-Bp1tUdg1USwIwvGZzsbKZrCK/img-uz05wK0H2DJBmWamMgNzym36.png?st=2024-03-08T19%3A27%3A33Z&se=2024-03-08T21%3A27%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-08T18%3A09%3A46Z&ske=2024-03-09T18%3A09%3A46Z&sks=b&skv=2021-08-06&sig=dF5LO%2BcG6SsPPGw%2BsLgRGe17JwvF5Ck...
